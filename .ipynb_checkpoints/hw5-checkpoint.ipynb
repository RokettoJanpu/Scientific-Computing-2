# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tol = 1.0e-14
itermax = 50
Tmax = 2*np.pi*(4/3)**(3/2)
y0 = np.array([0, 1/2, 2, 0])

# RHS
def func(y): 
    dy = np.zeros(4)
    aux = (y[2]**2 + y[3]**2)**(-3/2)
    dy[0] = -y[2]*aux
    dy[1] = -y[3]*aux
    dy[2] = y[0]
    dy[3] = y[1]
    return dy

# Jacobian of RHS
def Jac(y):
    Jac = np.zeros((4,4))
    aux1 = (y[2]**2 + y[3]**2)**(-5/2)
    aux2 = 3*y[2]*y[3]*aux1
    Jac[0,2] = (2*y[2]**2 - y[3]**2)*aux1
    Jac[0,3] = aux2
    Jac[1,2] = aux2
    Jac[1,3] = (2*y[3]**2 - y[2]**2)*aux1
    Jac[2,0] = 1
    Jac[3,1] = 1
    return Jac

# implicit midpoint rule
def IMPstep(y,h):
    k = np.linalg.solve(np.identity(4) - 1/2*h*Jac(y), func(y))
    for j in range(itermax):
        F = k - func(y + 1/2*h*k)
        if np.linalg.norm(F) < tol:
            break
        DF = np.identity(4) - 1/2*h*Jac(y + 1/2*h*k)
        k = k - np.linalg.solve(DF, F)
    return y + h*k

# Hamiltonian
def H(y):
    return 1/2*y[0]**2 + 1/2*y[1]**2 - (y[2]**2 + y[3]**2)**(-1/2)

# gradient of kinetic energy T
def dT(y):
    return y

# gradient of potential energy U
def dU(y):
    aux = (y[0]**2 + y[1]**2)**(-3/2)
    return np.array([-y[0]*aux, -y[1]*aux])

# Stoermer-Verlet method
def SVstep(y,h):
    p = np.array([y[0])

# %%
# run implicit midpoint rule for 3 values of Nsteps
for Nsteps in [100, 1000, 10000]:
    h = Tmax/Nsteps
    sol_IMP = np.zeros((Nsteps+1, 4))
    sol_IMP[0,:] = y0
    for j in range(Nsteps):
        sol_IMP[j+1,:] = IMPstep(sol_IMP[j,:], h)
        
    plt.rcParams.update({'font.size': 10})
    plt.plot(sol_IMP[:,2], sol_IMP[:,3])
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("orbit for IMP, {} steps".format(Nsteps))
    plt.savefig("IMP orbit {} steps.png".format(Nsteps))
    plt.show()
    
    t = np.arange(0, Tmax+h, h)
    plt.plot(t, [H(y) for y in sol_IMP])
    plt.xlabel("t")
    plt.ylabel("H")
    plt.title("H for IMP, {} steps".format(Nsteps))
    plt.savefig("IMP ham {} steps.png".format(Nsteps))
    plt.show()
    
    print(min(ham),max(ham))
# Out:
# -0.37500000000000466 -0.3749995101734309
# -0.37500000000000466 -0.3749995101734309
# -0.37500000000000466 -0.3749995101734309

# %%
a=[H(y) for y in sol_IMP]
print(max(a))
print(min(a))
# Out:
# -0.3749995101734309
# -0.37500000000000466

# %%
a=np.zeros((2, 4))
a[0,:]=[1,2,3,4]
a[1,:]=[5,6,7,8]
print(a)
print(H(a))
# Out:
# [[1. 2. 3. 4.]
#  [5. 6. 7. 8.]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8136\473721965.py in <module>
#       3 a[1,:]=[5,6,7,8]
#       4 print(a)
# ----> 5 print(H(a))
#
# ~\AppData\Local\Temp\ipykernel_8136\1099718861.py in H(y)
#       6 # Hamiltonian
#       7 def H(y):
# ----> 8     return 1/2*y[0]**2 + 1/2*y[1]**2 - (y[2]**2 + y[3]**2)**(-1/2)
#       9
#      10 # RHS
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
a=np.array([1,2,3,4])
print(a[0:2])
print(a[2:4])
# Out:
# [1 2]
# [3 4]
